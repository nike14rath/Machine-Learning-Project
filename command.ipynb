# %% [markdown]
# ### To setup a new enverinoment here

# %%
conda create -p venv python==3.8
conda activate venv/   # to activate it

# %% [markdown]
# ### To see the synchronization with my git REPO

# %%
git remote -v

# %% [markdown]
# ### To update everything from your REPO

# %%
git pull
# Out:
#   Cell In[1], line 1
#     git pull
#         ^
# SyntaxError: invalid syntax

# %% [markdown]
# Some times your venv will not show the easiest way to solve this problem to
# to install
#
# ``pip install ipykernel``

# %% [markdown]
# ### What is the difference in between using the Conda and Venve?
# One sentence that should click 💡
#
# venv = same Python, different packages
# conda = different Python + different packages + system libraries
#
# Conda says:
#
# “I will create a brand-new Python machine for this project.”
#
#
# When you use Python venv, you are saying:
#
# “I already have one Python machine installed on my system.
# I just want different sets of tools for different projects.”
