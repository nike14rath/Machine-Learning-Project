# %% [markdown]
# - Once the Data Ingestion Step is done make sure to add the .artifact folder into the .gitignore file.
#
# - data_transformation:<br>
#    1. Save_obj : is done in the utils folder where we get all of our common files that we are going to use.
#    2. Once we completed the code of the data_transformation.
#    3. then we checked by importing the data_transfomation there, got tran_data and test_data in the "main" function.
